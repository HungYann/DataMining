# %%
from selenium import webdriver

driver = webdriver.Chrome(executable_path=ChromeDriverBinaryPath)
driver.get("http://url you want to visit")
# Out:
# INFO: Overridden settings: {}
# 2020-02-26 15:14:31 [scrapy.extensions.telnet] INFO: Telnet Password: be6f2dfaba97b8f5
# 2020-02-26 15:14:31 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2020-02-26 15:14:31 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
# ...

# %%
# Find the candle list menu, click it to expand the menu
candle_unit_menu_ele = driver.find_element_by_id(":i")
candle_unit_menu_ele.click()

# After the menu expanded, click on a unit selection assigned by the user
candle_unit_ele = wait.until(EC.visibility_of_element_located((By.ID, CandleUnitIdTable[candle_unit]))
candle_unit_ele.click()
